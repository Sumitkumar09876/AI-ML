# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.model_selection import train_test_split
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\__init__.py:3
#       1 import typing
# ----> 3 from ._plot import LearningCurveDisplay, ValidationCurveDisplay
#       4 from ._search import GridSearchCV, ParameterGrid, ParameterSampler, RandomizedSearchCV
#       5 from ._split import (
#       6     BaseCrossValidator,
#       7     BaseShuffleSplit,
#    (...)
#      24     train_test_split,
#      25 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\model_selection\_plot.py:7
# ...
