# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumitkumar09876/AI-ML/blob/main/2_Null_Data_Removing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r"/content/Loan payments data.csv")
dataset.head(5)
# Out:
#        Loan_ID loan_status  Principal  terms effective_date    due_date  \
# 0  xqd20166231     PAIDOFF       1000     30     09-08-2016  10-07-2016
# 1  xqd20168902     PAIDOFF       1000     30     09-08-2016  10-07-2016
# 2  xqd20160003     PAIDOFF       1000     30     09-08-2016  10-07-2016
# 3  xqd20160004     PAIDOFF       1000     15     09-08-2016   9/22/2016
# 4  xqd20160005     PAIDOFF       1000     30     09-09-2016  10-08-2016
#
#      paid_off_time  past_due_days  age             education  Gender
# 0  9/14/2016 19:31            NaN   45  High School or Below    male
# 1  10-07-2016 9.00            NaN   50              Bechalor  female
# 2  9/25/2016 16:58            NaN   33              Bechalor  female
# 3  9/22/2016 20:00            NaN   27               college    male
# 4  9/23/2016 21:36            NaN   28               college  female

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.isnull()
# Out:
#      Loan_ID  loan_status  Principal  terms  effective_date  due_date  \
# 0      False        False      False  False           False     False
# 1      False        False      False  False           False     False
# 2      False        False      False  False           False     False
# 3      False        False      False  False           False     False
# 4      False        False      False  False           False     False
# ..       ...          ...        ...    ...             ...       ...
# 495    False        False      False  False           False     False
# 496    False        False      False  False           False     False
# 497    False        False      False  False           False     False
# 498    False        False      False  False           False     False
# 499    False        False      False  False           False     False
#
#      paid_off_time  past_due_days    age  education  Gender
# 0            False           True  False      False   False
# ...

# %%
dataset.shape
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=["past_due_days"],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataset.shape
# Out:
# (400, 10)

# %%
print('Data Lost:')
((500-400)/500)*100
# Out:
# Data Lost:
# 20.0
